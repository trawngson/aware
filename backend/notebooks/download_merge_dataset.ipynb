# %% [markdown]
# # Sanitized legacy workflow evidence
#
# This notebook preserves a reviewable record of the old exploratory merge. It is **not executable** and must not be used for training. All outputs, execution counts, credentials, direct package installation, download code, cleanup operations, random splitting, machine-specific paths, and shell commands were removed on 2026-07-22.
#
# The old workflow combined an unidentified Roboflow project, a Roboflow copy of TACO, and selected COCO classes. It renamed broad classes into narrower classes, deleted intermediate datasets/directories, used image-level random splitting, and exported a merged dataset without a reproducible source manifest. These properties make the result exploratory and non-reproducible. See `../Baseline Record 1.md`.
#
# The preserved legacy dataset and outputs remain on VAST but are excluded from all v1 training and evaluation. Use `remote_execution.ipynb` for the reviewed read-only preflight.
